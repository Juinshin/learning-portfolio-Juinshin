# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
from matplotlib import pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.plot(x, y_2,
         label='Y2 values', color='blue')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')    # For y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('fivethirtyeight')
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')

# %% [markdown]
# ### xkcd!

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.xkcd()

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create figure and axis
fig, ax = plt.subplots()

# Body
body = patches.Circle((0.5, 0.5), 0.4, color='gray')
ax.add_patch(body)

# Belly
belly = patches.Circle((0.5, 0.5), 0.3, color='white')
ax.add_patch(belly)

# Eyes
left_eye = patches.Circle((0.4, 0.6), 0.05, color='black')
right_eye = patches.Circle((0.6, 0.6), 0.05, color='black')
ax.add_patch(left_eye)
ax.add_patch(right_eye)

# Nose
nose = patches.Circle((0.5, 0.55), 0.03, color='black')
ax.add_patch(nose)

# Whiskers
whisker1 = plt.Line2D([0.45, 0.4], [0.55, 0.52], color='black')
whisker2 = plt.Line2D([0.55, 0.6], [0.55, 0.52], color='black')
ax.add_line(whisker1)
ax.add_line(whisker2)

# Ears
left_ear = patches.Circle((0.3, 0.7), 0.1, color='gray')
right_ear = patches.Circle((0.7, 0.7), 0.1, color='gray')
ax.add_patch(left_ear)
ax.add_patch(right_ear)

# Arms
left_arm = patches.Rectangle((0.1, 0.5), 0.1, 0.3, color='gray')
right_arm = patches.Rectangle((0.9, 0.5), -0.1, 0.3, color='gray')
ax.add_patch(left_arm)
ax.add_patch(right_arm)

# Legs
legs = patches.Rectangle((0.45, 0), 0.1, 0.5, color='gray')
ax.add_patch(legs)

# Set aspect ratio and limits
ax.set_aspect('equal', adjustable='datalim')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
plt.axis('off')

plt.title("Realistic Totoro")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
num_plots = len(x)
colors = ['blue', 'red', 'green', 'purple']  # Define colors for different plots

# Initialize empty lists to store line objects for each plot
lines = []
for i in range(num_plots):
    line, = ax.plot(x, np.sin(x - i), color=colors[i % len(colors)])  # Shift each plot to the right by i x-coordinates
    lines.append(line)

# Set title
plt.title('Replotting Sine Function with Shifted Curves')

# Show the animation
plt.show()
